# %% [markdown]
# # Companion Guide Stuff

# %%
import pandas as pd

df = pd.read_excel(r"C://Users//Melton//OneDrive//Documents//Afya//HPSJ//274CompanionGuideParsed.xlsx", engine = "openpyxl")

# %%
df.columns.values
# Out:
# array(['Loop\xa0\xa0', 'Reference\xa0', 'Name\xa0', 'Codes\xa0',
#        'Notes/Comments'], dtype=object)

# %%
import numpy as np
import math

_codes = df['Codes\xa0'].to_numpy().tolist()
codes = []

for i in df['Codes\xa0'].to_numpy().tolist():
    try:
        v = (float(i))
        if not (math.isnan(v)):
            codes.append(v)
    except:
        codes.append(i)
        pass
        
print(codes)
# Out:
# [3.0, 0.0, 'ZZ', 'ZZ\xa0', 'DHCS-PROV NETWK', '^', 405.0, 0.0, ':', 'PW', 'DHCS-PROV NETWK', '004050X109', 274.0, '004050X109\xa0', 28.0, 27.0, 'ACV', 'FI', 'NN', 40.0, 'DHCS\xa0\xa0', 'Managed\xa0\xa0', 'Care', 'QV', 'XX\xa0', '092, 093\xa0', 68.0, 77.0, 'XX', 'AJ\xa0', 'TE\xa0', 'EM\xa0', 'FX\xa0', 'ENG\xa0', 'A, B, C\xa0 or D', '092,\xa0\xa0', 93.0, 'C4\xa0', 'P7, P8\xa0', 'DJ', '1R, 1S,\xa0 1T, 1U,\xa0 1V, 1Y,\xa0 2E, 2S', 'F, M', 77.0, 68.0, '3E, 3G\xa0', 'N5', 30.0, 2.0, 'EQ\xa0', '1P\xa0', 'XX', 'ENG\xa0', 4.0, 'A, B,\xa0\xa0', 'C or D', '092,\xa0\xa0', 93.0, 68.0, '3E, 3G\xa0', 'YR\xa0', 'Y\xa0', 'N5']

# %%
_names = df['Name\xa0'].to_numpy().tolist()

# %%
import unicodedata

_references = df['Reference\xa0'].to_numpy().tolist()
references = []

for i in df['Reference\xa0'].to_numpy().tolist():
    try:
        v = (float(i))
        if not (math.isnan(v)):
            references.append(unicodedata.normalize("NFKD", v))
    except:
        references.append(unicodedata.normalize("NFKD", i))
        pass

# %%
names = []
for i,r in enumerate(_references):
    new_i = i
    try:
        # Usually, v will be nan, but what if not?
        v = float(r)
    except:
        # If v is a string, begin collecting "names"
        t_name = _names[new_i]
        new_i = i+1
        while(True):
            n = _names[new_i]
            try:
                # Usually, _v will be nan as well
                # If it is nan, leave loop and save the full
                # name of the header
                _v = float(n)
                if(math.isnan(_v)):
                    names.append(t_name)
                    break
            except:
                # Only combine if _references at the same
                # index is also a nan else, break
                __v = _references[new_i]
                try:
                    _r = float(__v)
                    if(math.isnan(_r)):
                        t_name = t_name + n
                        new_i += 1
                except:
                    names.append(t_name)
                    break

print(len(names))
# Out:
# 166

# %%
random_test_index = 0
print(references[10],names[10])
# Out:
# ISA13  Interchange  Control  Number

# %%
import numpy as np
import math

_loops = df['Loop\xa0\xa0'].to_numpy().tolist()
loops = []

for i in _loops:
    try:
        v = (float(i))
        if not (math.isnan(v)):
            loops.append(unicodedata.normalize("NFKD", v.strip()))
    except:
        loops.append(unicodedata.normalize("NFKD", i.strip()))
        pass
        
print(loops)
# Out:
# ['ID', 'ISA', 'IEA', 'GS', 'GE', 'ST', 'SE', 'BHT', '2100AA', '2100AB', '2100BA', '2100CA', '2120CA', '2140CA', '2100CB', '2100DA', '2110DA', '2120DA', '2140DA', '2100DB', '2100EA', '2120EA', '2140EA']

# %%
d = {}
for l in loops:
    _d = {}
    for i,m in enumerate(references):
        if(l in m):
            _d[m] = unicodedata.normalize("NFKD", names[i])
    d[l] = _d

# %%
loop_dict = {}
index = 0
while(True):
    _loop_storage = ''
    try:
        v = float(_loops[index])
    except:
        try:
            _loop_storage = _loops[index]
        except:
            break
        try:
            _ref_arr = [_references[index]]
        except:
            pass
        while(True):
            index+=1
            try:
                v = float(_loops[index])
                if(math.isnan(v)):
                    try:
                        _ref_arr.append(_references[index])
                    except:
                        pass
            except:
                break
            
        loop_dict[_loop_storage]=_ref_arr

# %%
c_dict = {}
for i in loop_dict:
    arr = []
    for j in loop_dict[i]:
        try:
            math.isnan(j)
        except:
            arr.append(j)
    c_dict[i] = arr

# %%
m_dict = {}
_index_ = 0
for i in c_dict:
    s_dict = {}
    for j in c_dict[i]:
        s_dict[j] = names[_index_]
        _index_+=1
    m_dict[i] = s_dict

# %%
m_dict
# Out:
# {'ID': {},
#  'ISA\xa0': {'ISA01\xa0': 'Authorization\xa0 Information\xa0Qualifier',
#   'ISA02\xa0': 'Authorization\xa0 Information',
#   'ISA03\xa0': 'Security\xa0\xa0Information\xa0\xa0Qualifier',
#   'ISA04\xa0': 'Security\xa0\xa0Information',
#   'ISA05\xa0': 'Interchange ID\xa0 Qualifier',
#   'ISA06\xa0': 'Interchange\xa0\xa0Sender ID',
#   'ISA07\xa0': 'Interchange ID\xa0 Qualifier',
#   'ISA08\xa0': 'Interchange\xa0\xa0Receiver ID',
#   'ISA11\xa0': 'Repetition\xa0\xa0Separator',
#   'ISA12\xa0': 'Interchange\xa0\xa0Control Version\xa0 Number',
#   'ISA13\xa0': 'Interchange\xa0\xa0Control\xa0\xa0Number',
#   'ISA14\xa0': 'Acknowledgem ent Requested',
#   'ISA16\xa0': 'Component\xa0\xa0Element\xa0\xa0SeparatorInterchange\xa0\xa0Control Trailer'},
#  'IEA\xa0': {'IEA02\xa0': 'Interchange\xa0\xa0Control\xa0\xa0NumberFunctional\xa0\xa0Group Header'},
#  'GS\xa0': {'GS01\xa0': 'Functional\xa0\xa0Identifier Code',
#   'GS02\xa0': "Application\xa0\xa0Sender's Code",
#   'GS03\xa0': "Application\xa0\xa0Receiver's\xa0\xa0Code",
#   'GS06\xa0': 'Group Control\xa0 Number',
#   'GS08\xa0': 'Version /\xa0\xa0Release /\xa0\xa0Industry\xa0\xa0Identifier CodeFunctional\xa0\xa0Group Trailer'},
#  'GE\xa0': {'GE02\xa0': 'Group Control\xa0 NumberTransaction\xa0\xa0Set Header'},
#  'ST\xa0': {'ST01\xa0': 'Transaction\xa0\xa0Set Identifier\xa0\xa0Code',
#   'ST02\xa0': 'Transaction\xa0\xa0Set Control\xa0\xa0Number',
#   'ST03\xa0': 'Implementation\xa0 Convention\xa0\xa0ReferenceTransaction\xa0\xa0Set Trailer'},
#  'SE\xa0': {'SE01\xa0': 'Number of\xa0\xa0Included\xa0\xa0Segments',
#   'SE02\xa0': 'Transaction\xa0\xa0Set Control\xa0\xa0Number'},
#  'BHT': {'BHT\xa0': 'Beginning of\xa0 Hierarchical \xa0Transaction',
#   'BHT01\xa0': 'Hierarchical\xa0 Structure\xa0\xa0Code',
#   'BHT02\xa0': 'Transaction\xa0 Set Purpose\xa0 Code',
#   'BHT03\xa0': 'Submitter\xa0\xa0Transaction\xa0 Identifier',
#   'BHT04\xa0': 'Transaction\xa0 Set Creation\xa0 Date',
#   'BHT05\xa0': 'Transaction\xa0 Set Creation\xa0 Time'},
#  '2100AA\xa0': {'NM1\xa0': 'Information\xa0 Source \xa0Name',
#   'NM101\xa0': 'Entity\xa0\xa0Identifier\xa0\xa0Code',
#   'NM103\xa0': 'Organization\xa0 Name',
#   'NM108\xa0': 'Identification\xa0 Code\xa0\xa0Qualifier',
#   'NM109\xa0': 'Information\xa0 Source\xa0\xa0Primary\xa0Identifier'},
#  '2100AB\xa0': {'NM1\xa0': 'Network\xa0\xa0Name',
#   'NM101\xa0': 'Entity\xa0\xa0Identifier\xa0\xa0Code',
#   'NM103\xa0': 'Organization\xa0 Name'},
#  '2100BA\xa0': {'NM1\xa0': 'Information\xa0 Receiver \xa0Name',
#   'NM101\xa0': 'Entity\xa0\xa0Identifier\xa0\xa0Code',
#   'NM103\xa0': 'Organization\xa0 Name'},
#  '2100CA\xa0': {'NM1\xa0': 'Provider\xa0\xa0Group Name',
#   'NM101\xa0': 'Entity\xa0\xa0Identifier Code',
#   'NM103\xa0': 'Provider\xa0\xa0Group Name',
#   'NM108\xa0': 'Identifier Code\xa0 Qualifier',
#   'NM109\xa0': 'Identification\xa0 Code',
#   'N2\xa0': 'Additional\xa0\xa0Provider \xa0Group Name \xa0Information',
#   'N201\xa0': 'Name\xa0',
#   'DTP\xa0': 'Provider\xa0\xa0Group’s \xa0Participation \xa0Dates',
#   'DTP01\xa0': 'Date/Time\xa0\xa0Qualifier',
#   'DTP03\xa0': 'Date Time\xa0\xa0Period'},
#  '2120CA\xa0': {'LQ\xa0': 'Provider\xa0\xa0Group’s Area \xa0of \xa0Specialization',
#   'LQ01\xa0': 'Code/List\xa0\xa0Qualifier Code',
#   'LQ02\xa0': 'Industry Code\xa0',
#   'TPB\xa0': 'Provider\xa0\xa0Group’s \xa0Network \xa0/Product Role'},
#  '2140CA\xa0': {'REF\xa0': 'Provider\xa0\xa0Group \xa0Identification \xa0Numbers'},
#  '2100CB\xa0': {'NM1\xa0': 'Affiliated\xa0\xa0Entity Name',
#   'N2\xa0': 'Affiliated\xa0\xa0Entity \xa0Additional \xa0Name \xa0Information'},
#  '2100DA\xa0': {'NM1\xa0': 'Site Name\xa0',
#   'NM101\xa0': 'Entity Identifier\xa0 Code',
#   'NM103\xa0': 'Site Name\xa0',
#   'NM108\xa0': 'Identifier Code\xa0 Qualifier',
#   'NM109\xa0': 'Identification\xa0\xa0Code',
#   'N2\xa0': 'Site/Location\xa0\xa0Additional \xa0Name \xa0Information',
#   'N201\xa0': 'Name\xa0',
#   'N202\xa0': 'Name\xa0',
#   'PER\xa0': 'Site Contact\xa0\xa0Information',
#   'PER01\xa0': 'Contact\xa0\xa0Function Code',
#   'PER03\xa0': 'Communication\xa0 Number\xa0\xa0Qualifier',
#   'PER04\xa0': 'Communication\xa0 Number',
#   'PER05\xa0': 'Communication\xa0 Number\xa0\xa0Qualifier',
#   'PER06\xa0': 'Communication\xa0 Number',
#   'PER07\xa0': 'Communication\xa0 Number\xa0\xa0Qualifier',
#   'PER08\xa0': 'Communication\xa0 Number',
#   'LUI\xa0': 'Foreign\xa0\xa0Languages \xa0Spoken at this Site',
#   'LUI02\xa0': 'Identification\xa0\xa0Code',
#   'LUI05\xa0': 'Language\xa0\xa0Proficiency\xa0\xa0Indicator',
#   'DTP\xa0': 'Site\xa0Participation \xa0Dates',
#   'DTP01\xa0': 'Date/Time\xa0\xa0Qualifier',
#   'DTP03\xa0': 'Date Time\xa0\xa0Period',
#   'WS\xa0': 'Work Schedule\xa0 at this Site',
#   'WS01\xa0': 'Office Hours\xa0\xa0Code',
#   'WS02\xa0': 'Office Hours\xa0\xa0Start Time',
#   'WS03\xa0': 'Office Hours\xa0\xa0End Time',
#   'CRC\xa0': 'Site Assistive\xa0\xa0Aid Information',
#   'CRC01\xa0': 'Provider\xa0\xa0Characteristics\xa0 and Resources',
#   'CRC03\xa0': 'Patient\xa0\xa0Acceptance\xa0\xa0Indicator',
#   'CRC03,\xa0': 'Site or Location\xa0 Assistive Aid\xa0\xa0',
#   'CRC04,\xa0': 'Indicator',
#   'CRC05,\xa0': nan,
#   'CRC06,\xa0': nan,
#   'CRC07': nan,
#   'PDI\xa0': 'Practice\xa0\xa0Restrictions at \xa0this Site',
#   'PDI01\xa0': 'Gender\xa0\xa0Restriction\xa0\xa0Code',
#   'PDI02\xa0': 'Age Range\xa0\xa0Minimum',
#   'PDI03\xa0': 'Age Range\xa0\xa0Maximum'},
#  '2110DA\xa0': {'NX1\xa0': 'Site Address\xa0\xa0Type',
#   'NX101\xa0': 'Entity\xa0\xa0Identification\xa0\xa0Code',
#   'N3\xa0': 'Site Street\xa0\xa0Address',
#   'N301\xa0': 'Site Address\xa0\xa0Line 1',
#   'N302\xa0': 'Site Address\xa0\xa0Line 2',
#   'N4\xa0': 'Site Geographic\xa0 Location',
#   'N401\xa0': 'Site City\xa0',
#   'N402\xa0': 'Site State\xa0',
#   'N403\xa0': 'Site Zip Code\xa0'},
#  '2120DA\xa0': {'LQ\xa0': 'Site Area of\xa0\xa0Specialization',
#   'LQ01\xa0': 'Code/List\xa0\xa0Qualifier Code',
#   'LQ02\xa0': 'Industry Code\xa0',
#   'TPB\xa0': 'Network Role at\xa0 this Site',
#   'TPB01\xa0': 'Provider Group\xa0 Network Role\xa0 Code'},
#  '2140DA\xa0': {'REF\xa0': 'Site\xa0\xa0Identification \xa0Numbers',
#   'REF01\xa0': 'Reference\xa0\xa0Identification\xa0\xa0Qualifier',
#   'REF02\xa0': 'Reference\xa0\xa0Identification'},
#  '2100DB\xa0': {'NM1\xa0': 'Affiliated Entity\xa0 Name',
#   'NM101\xa0': 'Entity Identifier\xa0 Code',
#   'NM102\xa0': 'Entity Qualifier\xa0',
#   'NM103\xa0': 'Name\xa0',
#   'NM108\xa0': 'Identification\xa0\xa0Code Qualifier',
#   'NM109\xa0': 'Identification\xa0\xa0Code',
#   'N2\xa0': 'Affiliated Entity\xa0 Additional \xa0Name \xa0Information',
#   'N201\xa0': 'Name\xa0'},
#  '2100EA\xa0': {'NM1\xa0': 'Provider Name\xa0',
#   'NM101\xa0': 'Entity Identifier\xa0 Code',
#   'NM103\xa0': 'Last Name\xa0',
#   'NM104\xa0': 'First Name\xa0',
#   'NM105\xa0': 'Middle Name\xa0',
#   'NM107\xa0': 'Suffix\xa0',
#   'NM108\xa0': 'Identifier Code\xa0 Qualifier',
#   'NM109\xa0': 'Identification\xa0\xa0Code',
#   'N2\xa0': 'Additional\xa0\xa0Provider Name \xa0Information',
#   'N201\xa0': 'Name\xa0',
#   'N202\xa0': 'Name\xa0',
#   'DEG\xa0': 'Providers\xa0\xa0Degree \xa0Information',
#   'DEG01\xa0': 'Academic\xa0\xa0Degree Code',
#   'DEG04\xa0': 'Provider\xa0\xa0Professional\xa0\xa0Designation',
#   'LUI\xa0': 'Foreign\xa0\xa0Languages \xa0Spoken by this \xa0provider',
#   'LUI02\xa0': 'Identification\xa0\xa0Code',
#   'LUI05\xa0': 'Language\xa0\xa0Proficiency\xa0\xa0Indicator',
#   'DTP\xa0': 'Affiliation\xa0\xa0Participation \xa0Dates',
#   'DTP01\xa0': 'Date/Time\xa0\xa0Qualifier',
#   'DTP03\xa0': 'Date Time\xa0\xa0Period'},
#  '2120EA\xa0': {'LQ\xa0': 'Provider\xa0\xa0Group’s Area \xa0of \xa0Specialization',
#   'LQ01\xa0': 'Code/List\xa0\xa0Qualifier Code',
#   'LQ02\xa0': 'Industry Code\xa0',
#   'TPB\xa0': 'Network Role\xa0 at this Site',
#   'TPB01\xa0': 'Provider Group\xa0 Network Role\xa0 Code',
#   'YNQ\xa0': 'Provider’s\xa0\xa0Board \xa0Certification',
#   'YNQ01\xa0': 'Condition\xa0\xa0Indicator',
#   'YNQ02\xa0': 'Response\xa0\xa0Code'},
#  '2140EA\xa0': {'REF\xa0': 'Provider\xa0\xa0Identification \xa0Numbers',
#   'REF01\xa0': 'Reference\xa0\xa0Identification\xa0\xa0Qualifier',
#   'REF02\xa0': 'Reference\xa0\xa0Identification'}}

# %%
test = 'asdf'
test2 = 'asdf2'
print(test in test2)
# Out:
# True

# %% [markdown]
# # Input File Stuff

# %%
input_file = []

with open(r"C://Users//Melton//OneDrive//Documents//Afya//HPSJ//Data_readable.txt",'r') as f:
    temp = f.read()
    [input_file.append(t) for t in temp.split('\n')]

# %%
all_ = []
for L in input_file:
    line = L.split('*')
    all_.append(line)

# %% [markdown]
# # Final Output

# %%
import json
with open(r"C://Users//Melton//OneDrive//Documents//Afya//HPSJ//dat.json",'r') as f:
    test_ = json.load(f)

# %%
print(test_)
# Out:
# [{'npi': '', 'first_name': 'Jon', 'last_name': 'doe', 'dob': '03-22-1996', 'hospital_name': 'World health care', 'email': 'jon@doe.com', 'password': '', 'mobile': '123456789', 'experience': 10, 'image_url': 'qwerrrrrrrrrrrr', 'spec_id': '7f8f5fc0-57d3-11ea-99c5-697c53e23e48', 'about': 'MMBS', 'org_details': [{'org_id': '', 'roles': ['']}]}, {'npi': '', 'first_name': 'Ray', 'last_name': 'Ken', 'dob': '03-22-1996', 'hospital_name': 'United health care', 'email': 'Ken@ray.com', 'password': '', 'mobile': '123456789', 'experience': 10, 'image_url': 'qwerrrrrrrrrrrr', 'spec_id': '7f8f5fc0-57d3-11ea-99c5-697c53e23e48', 'about': 'Mbbs', 'org_details': [{'org_id': '', 'roles': ['']}]}]

# %%
print(test_[0].keys())
# Out:
# dict_keys(['npi', 'first_name', 'last_name', 'dob', 'hospital_name', 'email', 'password', 'mobile', 'experience', 'image_url', 'spec_id', 'about', 'org_details'])

# %%
# Can do AJ -> 1P, AJ -> 1P
pcp_arr = []
one_pcp = {}
for i,_L in enumerate(all_):
# npi = 2100EA NM109
# Look for 1P
    if( '1P' in _L ):
        one_pcp['npi'] = _L[9][:-1]
# first_name = 2100EA NM104
# Look for 1P
        one_pcp['first_name'] = _L[4]
# last_name = 2100EA NM103
# Look for 1P
        one_pcp['last_name'] = _L[3]
# dob = 2100EA NM201
# between the 3rd and 4th ;
# Look for 1P
        nm201 = (all_[i+1][1]).split(';')[3]
        one_pcp['dob'] = nm201[4:6] +'-'+ nm201[6:] +'-' + nm201[:4]
# hospital_name = ???
        pcp_arr.append(one_pcp)
        one_pcp = {}
# email = 2100DA PER06
# AJ
    if( 'AJ' in _L ):
        one_pcp['email'] = _L[6]
# password ???

# mobile = 2100DA PER04
# AJ
        one_pcp['mobile'] = _L[4]
        
        pcp_arr.append(one_pcp)
        one_pcp = {}
# experience = ??? degree?

# image_url ???

# spec_id ???

# about ???

# org_details: [{'org_id': '', 'roles': ['']}]

# %%
pcp_arr
# Out:
# [{'email': 'nsparks@thekkek.com', 'mobile': '2092391222'},
#  {'email': 'juanell.seward@davita.com', 'mobile': '2095431720'},
#  {'email': 'rivereyes@rovc.biz', 'mobile': '2098693300'},
#  {'npi': '1760566434',
#   'first_name': 'Brian',
#   'last_name': 'Elliott',
#   'dob': '07-11-1963',
#   'email': 'jill@careonehomehealth.net',
#   'mobile': '2096328888'},
#  {'email': 'drreddy@centralvalleycardiovascular.com', 'mobile': '2092397852'},
#  {'npi': '1184706343',
#   'first_name': 'Venkata',
#   'last_name': 'Emani',
#   'dob': '07-23-1965',
#   'email': 'drreddy@centralvalleycardiovascular.com',
#   'mobile': '2095471079'},
#  {'npi': '1184706343',
#   'first_name': 'Venkata',
#   'last_name': 'Emani',
#   'dob': '07-23-1965',
#   'email': 'bmarftinez@dignityhealth.org',
#   'mobile': '2097229729'},
#  {'npi': '1568583201',
#   'first_name': 'Gerald',
#   'last_name': 'Main',
#   'dob': '02-07-1945',
#   'email': 'eagmedical@gmail.com',
#   'mobile': '2095215150'},
#  {'npi': '1447219662',
#   'first_name': 'Eleuterio',
#   'last_name': 'Go',
#   'dob': '05-03-1955',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2093333066'},
#  {'npi': '1457344293',
#   'first_name': 'Rolando',
#   'last_name': 'Simeon',
#   'dob': '10-08-1949',
#   'email': 'mary.a.sprock@questdiagnostics.com',
#   'mobile': '2093339796'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2099562624'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2099330255'},
#  {'email': 'mary.a.sprock@questdiagnostics.com~', 'mobile': '2099324000'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2098301763'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2095491197'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2095268130'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2095754559'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2095799396'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2093674468'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2098254158'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2092391436'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2098232560'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2099515831'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2099551288'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2099562815'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2099421889'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2099421927'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2099562684'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2099412468'},
#  {'email': 'wendy.e.guzman@questdiagnostics.com', 'mobile': '8187375200'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2098301342'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2095690379'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2095237918'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2098623057'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2098452911'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2098925236'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2096696245'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2096689163'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2095810155'},
#  {'email': 'mary.a.sprock@questdiagnostics.com', 'mobile': '2097250658'},
#  {'email': 'tvupediatrics@yahoo.com', 'mobile': '2099573901'},
#  {'npi': '1770555013',
#   'first_name': 'Lien',
#   'last_name': 'Nguyen',
#   'dob': '01-20-1937',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2095211028'},
#  {'npi': '1023000502',
#   'first_name': 'L. Edward',
#   'last_name': 'Elliott',
#   'dob': '08-13-1940',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096567299'},
#  {'email': 'christine@adlhealthcaresupplies.com', 'mobile': '9166240900'},
#  {'email': 'live@winecountrycarecenter.com', 'mobile': '2093343760'},
#  {'email': 'tvhhci@yahoo.com', 'mobile': '2099570708'},
#  {'email': 'aburke@ddanzinc.com', 'mobile': '2094776352'},
#  {'email': 'aburke@ddanzinc.com', 'mobile': '5592521700'},
#  {'email': 'gia.smith@centralvalleyspecialty.org', 'mobile': '2095290516'},
#  {'email': 'providerservices@hpsj.com~', 'mobile': '2093330905'},
#  {'email': 'melissa3.young2@tenethealth.com', 'mobile': '2092396008'},
#  {'npi': '1326385659',
#   'first_name': 'Deval',
#   'last_name': 'Bhatt',
#   'dob': '10-19-1983',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094664341'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094775252'},
#  {'email': 'devanie.seay@eskaton.org', 'mobile': '2099563444'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094660456'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094774817'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2099488762'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095290516'},
#  {'email': 'karenr@aspenskilledhealth.com', 'mobile': '2094733004'},
#  {'email': 'kasandriam@acaciaparknursing.com', 'mobile': '2095235667'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098622862'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095771055'},
#  {'email': 'amanda.miller@linkshealth.com', 'mobile': '2093343760'},
#  {'email': 'rbmalmberg@covenantcareathome.org', 'mobile': '2092505200'},
#  {'email': 'rbmalmberg@covenantcareathome.org', 'mobile': '2092505200'},
#  {'email': 'rbmalmberg@covenantcareathome.org', 'mobile': '2092505200'},
#  {'email': 'providerservices@hpsj.com~', 'mobile': '2093343411'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098477501'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094686600'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2099432000'},
#  {'email': 'gia.smith@centralvalleyspecialty.org', 'mobile': '2092487700'},
#  {'email': 'juleelopes@gmail.com~', 'mobile': '2099449100'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2093330905'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094774380'},
#  {'npi': '1093752636',
#   'first_name': 'Hort',
#   'last_name': 'Seng',
#   'dob': '01-25-1952',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2099516072'},
#  {'npi': '1114963873',
#   'first_name': 'Shou-I',
#   'last_name': 'Lin',
#   'dob': '01-01-1945',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094655655'},
#  {'npi': '1992897292',
#   'first_name': 'Christopher',
#   'last_name': 'Mills',
#   'dob': '12-28-1943',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2098359029'},
#  {'npi': '1306825237',
#   'first_name': 'Natesan',
#   'last_name': 'Rama',
#   'dob': '04-22-1941',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2099399512'},
#  {'npi': '1962473983',
#   'first_name': 'Geny',
#   'last_name': 'Burgos',
#   'dob': '09-15-1952',
#   'email': 'galtmedical@yahoo.com@yahoo.com',
#   'mobile': '2097454633'},
#  {'npi': '1346244050',
#   'first_name': 'Ayman',
#   'last_name': 'Damen',
#   'dob': '09-17-1952',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094774485'},
#  {'npi': '1932214517',
#   'first_name': 'Dumrong',
#   'last_name': 'Jirasutayasuntorn',
#   'dob': '11-02-1944',
#   'email': 'burbano@comcast.net',
#   'mobile': '2098331628'},
#  {'npi': '1649274663',
#   'first_name': 'Wivina',
#   'last_name': 'Urbano',
#   'dob': '12-24-1958',
#   'email': 'drbigbirdmd@gmail.com',
#   'mobile': '2094721470'},
#  {'npi': '1851328991',
#   'first_name': 'Charles',
#   'last_name': 'McCormick',
#   'dob': '08-01-1949',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096691692'},
#  {'npi': '1801908371',
#   'first_name': 'Jagmohan',
#   'last_name': 'Bhinder',
#   'dob': '01-03-1958',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2095271870'},
#  {'npi': '1477659001',
#   'first_name': 'Tri',
#   'last_name': 'Pham',
#   'dob': '08-10-1947',
#   'email': 'selsakr@gmail.com',
#   'mobile': '2093330293'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098336118'},
#  {'npi': '1376514489',
#   'first_name': 'Mahesh',
#   'last_name': 'Modi',
#   'dob': '12-21-1951',
#   'email': 'orthogold@aol.com',
#   'mobile': '2095244438'},
#  {'npi': '1982652459',
#   'first_name': 'Michael',
#   'last_name': 'Purnell',
#   'dob': '09-18-1958',
#   'email': 'orthogold@aol.com',
#   'mobile': '2095244438'},
#  {'npi': '1629026141',
#   'first_name': 'William',
#   'last_name': 'Holmes',
#   'dob': '06-15-1966',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2093662360'},
#  {'npi': '1144232349',
#   'first_name': 'Mani',
#   'last_name': 'Mahdyoon',
#   'dob': '03-15-1960',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2099436740'},
#  {'npi': '1841379856',
#   'first_name': 'Madelaine',
#   'last_name': 'Aquino',
#   'dob': '11-05-1967',
#   'email': 'bkl1003@gmail.com',
#   'mobile': '2095234999'},
#  {'npi': '1598729410',
#   'first_name': 'Binh',
#   'last_name': 'Le',
#   'dob': '10-03-1948',
#   'email': 'officestaff@allenhoekod.com',
#   'mobile': '2095992216'},
#  {'npi': '1649284316',
#   'first_name': 'Allen',
#   'last_name': 'Hoek',
#   'dob': '06-30-1960',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2095722700'},
#  {'email': 'jgreenbargmd@att.net', 'mobile': '2096327633'},
#  {'npi': '1619990355',
#   'first_name': 'James',
#   'last_name': 'Greenbarg',
#   'dob': '10-04-1961',
#   'email': 'mfrancisco@franciscomedical.com',
#   'mobile': '2099483009'},
#  {'npi': '1598721003',
#   'first_name': 'Marie',
#   'last_name': 'Francisco',
#   'dob': '09-18-1961',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094666871'},
#  {'npi': '1033142088',
#   'first_name': 'Kwabena',
#   'last_name': 'Adubofour',
#   'dob': '02-01-1958',
#   'email': 'nininireddy@yahoo.com',
#   'mobile': '2099464000'},
#  {'npi': '1689775819',
#   'first_name': 'Raghunath',
#   'last_name': 'Reddy',
#   'dob': '05-19-1960',
#   'email': 'mkkod@yahoo.com',
#   'mobile': '2099572824'},
#  {'npi': '1851326185',
#   'first_name': 'Michael',
#   'last_name': 'Klopping',
#   'dob': '05-01-1958',
#   'email': 'advancedmb@comcast.net',
#   'mobile': '2098255864'},
#  {'npi': '1225031693',
#   'first_name': 'Michael',
#   'last_name': 'Davis',
#   'dob': '12-24-1954',
#   'email': 'helene@novesterasmd.com',
#   'mobile': '2098333386'},
#  {'npi': '1659324101',
#   'first_name': 'Helene',
#   'last_name': 'Novesteras',
#   'dob': '10-24-1954',
#   'email': 'sheree.clarke@avalonhealthcare.com',
#   'mobile': '2095261755'},
#  {'email': 'ecastockton@yahoo.com', 'mobile': '2094770296'},
#  {'npi': '1689707713',
#   'first_name': 'Mark',
#   'last_name': 'Komure',
#   'dob': '02-19-1952',
#   'email': 'dorene.griffith@21co.com',
#   'mobile': '2094721848'},
#  {'npi': '1598793507',
#   'first_name': 'Vitune',
#   'last_name': 'Vongtama',
#   'dob': '12-18-1939',
#   'email': 'reception@fredachinod.com',
#   'mobile': '2098922161'},
#  {'npi': '1982645420',
#   'first_name': 'Freda',
#   'last_name': 'Chin',
#   'dob': '07-10-1970',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094660678'},
#  {'npi': '1780697987',
#   'first_name': 'Earl',
#   'last_name': 'Taylor',
#   'dob': '01-24-1933',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2092398086'},
#  {'npi': '1477530236',
#   'first_name': 'Yong',
#   'last_name': 'Shih',
#   'dob': '02-02-1972',
#   'email': 'shesofly50@gmail.com',
#   'mobile': '2098361155'},
#  {'npi': '1831162999',
#   'first_name': 'Thomas',
#   'last_name': "O'Neil",
#   'dob': '07-21-1952',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2099483000'},
#  {'npi': '1609840479',
#   'first_name': 'Anan',
#   'last_name': 'Faidi',
#   'dob': '11-24-1959',
#   'email': 'felixsanchezmd@att.net',
#   'mobile': '2096678544'},
#  {'npi': '1366521650',
#   'first_name': 'Felix',
#   'last_name': 'Sanchez',
#   'dob': '04-17-1954',
#   'email': 'delpainemd@yahoo.com',
#   'mobile': '2099514100'},
#  {'npi': '1851452213',
#   'first_name': 'Dennis',
#   'last_name': 'Delpaine',
#   'dob': '08-19-1951',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094676820'},
#  {'npi': '1346239613',
#   'first_name': 'Albina',
#   'last_name': 'Benabaye',
#   'dob': '09-09-1942',
#   'email': 'hcmdpm@aol.com',
#   'mobile': '2098239378'},
#  {'npi': '1295709285',
#   'first_name': 'Howard',
#   'last_name': 'Miller',
#   'dob': '04-24-1947',
#   'email': 'carolyn@blakemore4hearing.com',
#   'mobile': '2096349327'},
#  {'email': 'lwilson@coventcare.com', 'mobile': '2093331222'},
#  {'email': 'glmiller07@gmail.com', 'mobile': '2098237146'},
#  {'npi': '1043282262',
#   'first_name': 'Gregory',
#   'last_name': 'Miller',
#   'dob': '06-20-1951',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2093349462'},
#  {'npi': '1710012117',
#   'first_name': 'Elizabeth',
#   'last_name': 'Hereford',
#   'dob': '07-23-1954',
#   'email': 'sgoldberg45@yahoo.com',
#   'mobile': '2099482001'},
#  {'npi': '1124053079',
#   'first_name': 'Steven',
#   'last_name': 'Goldberg',
#   'dob': '06-13-1947',
#   'email': 'rclairmdoffice@gmail.com',
#   'mobile': '2093680285'},
#  {'npi': '1285723502',
#   'first_name': 'Ramnik',
#   'last_name': 'Clair',
#   'dob': '08-27-1951',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094664222'},
#  {'npi': '1609826288',
#   'first_name': 'M',
#   'last_name': 'Karabala',
#   'dob': '07-18-1949',
#   'email': 'marissa@emeraldrecovery.org',
#   'mobile': '2098231788'},
#  {'email': 'jo@californiaskinlaser.com', 'mobile': '2099564260'},
#  {'npi': '1376649269',
#   'first_name': 'Gerald',
#   'last_name': 'Bock',
#   'dob': '07-21-1940',
#   'email': 'pdold@medrcm360.com',
#   'mobile': '2098330998'},
#  {'npi': '1194793182',
#   'first_name': 'Praveena',
#   'last_name': 'Sarma',
#   'dob': '06-09-1967',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094731011'},
#  {'npi': '1629028923',
#   'first_name': 'Craig',
#   'last_name': 'Garfolo',
#   'dob': '11-07-1955',
#   'email': 'carol.schantz@gmail.com',
#   'mobile': '2093346325'},
#  {'npi': '1518909126',
#   'first_name': 'Mazen',
#   'last_name': 'Mardini',
#   'dob': '11-28-1949',
#   'email': 'nora91159@yahoo.com',
#   'mobile': '2094915370'},
#  {'npi': '1922199959',
#   'first_name': 'Michael',
#   'last_name': 'Rossini',
#   'dob': '10-23-1953',
#   'email': 'karen.lodiheart@comcast.net',
#   'mobile': '2093343278'},
#  {'npi': '1780688515',
#   'first_name': 'Steven',
#   'last_name': 'Block',
#   'dob': '07-24-1945',
#   'email': 'dfacione@5ssl.com',
#   'mobile': '2094662066'},
#  {'email': 'drhatton@gotnet.net', 'mobile': '2094644832'},
#  {'npi': '1588778054',
#   'first_name': 'Patricia',
#   'last_name': 'Hatton',
#   'dob': '04-16-1950',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2093342020'},
#  {'npi': '1205940889',
#   'first_name': 'William',
#   'last_name': 'Henshaw',
#   'dob': '11-27-1944',
#   'email': 'lensermd@yahoo.com',
#   'mobile': '2095728528'},
#  {'npi': '1275504524',
#   'first_name': 'Brian',
#   'last_name': 'Lenser',
#   'dob': '05-16-1966',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2093331441'},
#  {'npi': '1457344293',
#   'first_name': 'Rolando',
#   'last_name': 'Simeon',
#   'dob': '10-08-1949',
#   'email': 'drgbwilson@att.net',
#   'mobile': '2099510498'},
#  {'npi': '1811993629',
#   'first_name': 'G',
#   'last_name': 'Wilson',
#   'dob': '09-23-1946',
#   'email': 'wilsonoptometry@att.net',
#   'mobile': '2095247870'},
#  {'npi': '1811993629',
#   'first_name': 'G',
#   'last_name': 'Wilson',
#   'dob': '09-23-1946',
#   'email': 'lydia@benkle.com',
#   'mobile': '2094655047'},
#  {'npi': '1669452801',
#   'first_name': 'David',
#   'last_name': 'Benkle',
#   'dob': '08-21-1954',
#   'email': 'modernoptometric@gmail.com',
#   'mobile': '2093332221'},
#  {'npi': '1124066931',
#   'first_name': 'Lien',
#   'last_name': 'Nguyen',
#   'dob': '06-13-1976',
#   'email': 'judee@stocktoncardio.com',
#   'mobile': '2099481234'},
#  {'npi': '1457511628',
#   'first_name': 'Amod',
#   'last_name': 'Tendulkar',
#   'dob': '10-28-1974',
#   'email': 'stanislaus@elite.net',
#   'mobile': '2095798800'},
#  {'npi': '1508991993',
#   'first_name': 'Michael',
#   'last_name': 'Sakamoto',
#   'dob': '04-11-1954',
#   'email': 'graceyfrheaven@yahoo.com',
#   'mobile': '2095224005'},
#  {'npi': '1740481043',
#   'first_name': 'Lorenzo',
#   'last_name': 'Aguilar',
#   'dob': '08-10-1956',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096561577'},
#  {'npi': '1255445557',
#   'first_name': 'Daryl',
#   'last_name': 'Bailie',
#   'dob': '03-07-1955',
#   'email': 'cbedolla@plannedparenthood.org',
#   'mobile': '2094662081'},
#  {'email': 'cbedolla@plannedparenthood.org', 'mobile': '2094774103'},
#  {'npi': '1275898835',
#   'first_name': 'Mary',
#   'last_name': 'McClellan',
#   'dob': '03-28-1985',
#   'email': 'cbedolla@plannedparenthood.org',
#   'mobile': '2092392528'},
#  {'email': 'cbedolla@plannedparenthood.org', 'mobile': '2098358910'},
#  {'email': 'cbedolla@plannedparenthood.org', 'mobile': '2095792300'},
#  {'email': 'cbedolla@plannedparenthood.org', 'mobile': '2097237751'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2096349461'},
#  {'npi': '1225240906',
#   'first_name': 'Noel',
#   'last_name': 'Zomalan',
#   'dob': '12-27-1969',
#   'email': 'ngactran@gmail.com',
#   'mobile': '2094732833'},
#  {'npi': '1912001363',
#   'first_name': 'Ngac',
#   'last_name': 'Tran',
#   'dob': '09-07-1947',
#   'email': 'office@dameronhospital.org',
#   'mobile': '2094669694'},
#  {'npi': '1396792339',
#   'first_name': 'Christopher',
#   'last_name': 'Arismendi',
#   'dob': '04-13-1960',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096670543'},
#  {'npi': '1912000811',
#   'first_name': 'E',
#   'last_name': 'Faraji',
#   'dob': '03-30-1965',
#   'email': 'tracyurology@gmail.com',
#   'mobile': '2098241313'},
#  {'npi': '1851368054',
#   'first_name': 'Salman',
#   'last_name': 'Razi',
#   'dob': '05-17-1967',
#   'email': 'tracyurology@gmail.com',
#   'mobile': '2098333449'},
#  {'npi': '1851368054',
#   'first_name': 'Salman',
#   'last_name': 'Razi',
#   'dob': '05-17-1967',
#   'email': 'office@drpontius.net',
#   'mobile': '2094770726'},
#  {'npi': '1609916246',
#   'first_name': 'Michael',
#   'last_name': 'Pontius',
#   'dob': '11-11-1952',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096675255'},
#  {'npi': '1063475614',
#   'first_name': 'Linh',
#   'last_name': 'Huynh',
#   'dob': '08-10-1968',
#   'email': 'kdeverteuil@windsorcares.com',
#   'mobile': '7076447401'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '9166859525'},
#  {'email': 'evanwalleghem@windsorcares.com', 'mobile': '9164820465'},
#  {'email': 'info@heartofthevalley.us', 'mobile': '9254160100'},
#  {'npi': '1497736201',
#   'first_name': 'Andrew',
#   'last_name': 'Maxwell',
#   'dob': '09-03-1963',
#   'email': 'mariadatdrmallorca@yahoo.com',
#   'mobile': '2092394515'},
#  {'npi': '1184683302',
#   'first_name': 'Florinda',
#   'last_name': 'Mallorca',
#   'dob': '08-06-1951',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '9252406300'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094646422'},
#  {'npi': '1023048865',
#   'first_name': 'Miroslav',
#   'last_name': 'Djokic',
#   'dob': '07-31-1964',
#   'email': 'marinak@blossomridge.net',
#   'mobile': '8009916147'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094615391'},
#  {'npi': '1629158340',
#   'first_name': 'Edward',
#   'last_name': 'Greenleaf',
#   'dob': '08-16-1952',
#   'email': 'mainfaxkhan@gmail.com',
#   'mobile': '2098241230'},
#  {'npi': '1053399980',
#   'first_name': 'Abdul',
#   'last_name': 'Khan',
#   'dob': '11-02-1964',
#   'email': 'eric@icshomecare.com',
#   'mobile': '5597342896'},
#  {'email': 'nctvillamor@yahoo.com', 'mobile': '2094655107'},
#  {'npi': '1154318764',
#   'first_name': 'Jerry',
#   'last_name': 'Soung',
#   'dob': '01-31-1973',
#   'email': 'valerie@valleymedicaltransport.com',
#   'mobile': '5597348743'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2093332020'},
#  {'npi': '1750375440',
#   'first_name': 'Kathryn',
#   'last_name': 'Larsson',
#   'dob': '08-20-1962',
#   'email': 'tbeam@laurenceorthopedic.com',
#   'mobile': '9258272062'},
#  {'email': 'tbeam@laurenceorthopedic.com', 'mobile': '5106582062'},
#  {'email': 'sutterhearingaidcenter@gmail.com', 'mobile': '2094662443'},
#  {'email': 'dnantt@lodihealth.org', 'mobile': '2093397610'},
#  {'email': 'jmallari@lifeguardhomehealth.com', 'mobile': '9252710221'},
#  {'email': 'contactus@wessonhearing.com', 'mobile': '2098232107'},
#  {'email': '5allison@sbcglobal.net', 'mobile': '2098323222'},
#  {'npi': '1578749776',
#   'first_name': 'Howard',
#   'last_name': 'Allison',
#   'dob': '06-15-1936',
#   'email': 'cbartz@modrad.com',
#   'mobile': '2096685210'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098352992'},
#  {'npi': '1528039799',
#   'first_name': 'Ripudaman',
#   'last_name': 'Beniwal',
#   'dob': '11-20-1967',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2092390515'},
#  {'npi': '1528039799',
#   'first_name': 'Ripudaman',
#   'last_name': 'Beniwal',
#   'dob': '11-20-1967',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094671173'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '9164893651'},
#  {'email': 'suzanne@betterhearingcenter.com', 'mobile': '2099571744'},
#  {'email': 'serina@freedomhme.com', 'mobile': '5107999920'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2093833123'},
#  {'email': 'growe@infinitycares.com', 'mobile': '8002941461'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '7076884712'},
#  {'npi': '1871764605',
#   'first_name': 'James',
#   'last_name': 'Aguilar',
#   'dob': '02-13-1970',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094772737'},
#  {'email': 'lisa@mobilityplusofca.com', 'mobile': '2095522244'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2096474545'},
#  {'npi': '1356483887',
#   'first_name': 'Noel',
#   'last_name': 'David',
#   'dob': '09-14-1955',
#   'email': 'providerservices@hpsj.com~',
#   'mobile': '9164532000'},
#  {'email': 'digna_cabrera@phhs-inc.com', 'mobile': '2094780758'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095372882'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2099432118'},
#  {'email': 'egomez82@gmail.com', 'mobile': '2094662546'},
#  {'email': 'kknobelauch@hanger.com', 'mobile': '2094662546'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '5592211933'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094841488'},
#  {'npi': '1487611026',
#   'first_name': 'Shahin',
#   'last_name': 'Laghaee',
#   'dob': '09-22-1965',
#   'email': 'bhuston8273@hotmail.com',
#   'mobile': '2095253176'},
#  {'npi': '1518991983',
#   'first_name': 'Armand',
#   'last_name': 'Hernandez',
#   'dob': '09-23-1950',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '5593533000'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '4154764173'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '5104283000'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098336118'},
#  {'npi': '1376514489',
#   'first_name': 'Mahesh',
#   'last_name': 'Modi',
#   'dob': '12-21-1951',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096698538'},
#  {'npi': '1619098142',
#   'first_name': 'Nancy',
#   'last_name': 'Silva',
#   'dob': '05-11-1948',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2098330268'},
#  {'npi': '1093756835',
#   'first_name': 'Jin-Mei',
#   'last_name': 'Woan',
#   'dob': '10-30-1951',
#   'email': 'susancowan6@hotmail.com~',
#   'mobile': '2096022067'},
#  {'npi': '1932230059',
#   'first_name': 'Susan',
#   'last_name': 'Cowan',
#   'dob': '06-02-1944',
#   'email': 'sonya@scs-lmft.com',
#   'mobile': '2096001531'},
#  {'npi': '1952566515',
#   'first_name': 'Sonya',
#   'last_name': 'Serna',
#   'dob': '12-03-1974',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2093692319'},
#  {'npi': '1477530236',
#   'first_name': 'Yong',
#   'last_name': 'Shih',
#   'dob': '02-02-1972',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096688030'},
#  {'npi': '1265656417',
#   'first_name': 'Fariba',
#   'last_name': 'Amani',
#   'dob': '09-06-1969',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2098351500'},
#  {'npi': '1932168911',
#   'first_name': 'Min',
#   'last_name': 'Zheng',
#   'dob': '09-14-1960',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2098306558'},
#  {'npi': '1932168911',
#   'first_name': 'Min',
#   'last_name': 'Zheng',
#   'dob': '09-14-1960',
#   'email': 'dawnrodriguez@findurjourney.com',
#   'mobile': '2096883529'},
#  {'npi': '1710042791',
#   'first_name': 'Dawn',
#   'last_name': 'Rodriguez',
#   'dob': '03-21-1972',
#   'email': 'sf49erswin@gmail.com~',
#   'mobile': '2092059084'},
#  {'npi': '1316092901',
#   'first_name': 'Christine',
#   'last_name': 'Sumner',
#   'dob': '12-17-1951',
#   'email': 'stockton@nsm-seating.com',
#   'mobile': '2099549311'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '5592224060'},
#  {'email': 'kathy.padilla@dignityhealth.org~', 'mobile': '2095643600'},
#  {'email': 'mikesmithmdoffice@gmail.com', 'mobile': '2094781536'},
#  {'npi': '1720179385',
#   'first_name': 'Michael',
#   'last_name': 'Smith',
#   'dob': '07-16-1960',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '5592265683'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '5592220793'},
#  {'email': 'providerservices@hpsj.com~', 'mobile': '5593204000'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098582409'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098470367'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2097452405'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095212094'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '9163916011'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '4088429311'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '6503270511'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '6509682990'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '6509415255'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '4082483736'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '8314760770'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '4087797346'},
#  {'email': 'bom@lincolnsquarerehab.com', 'mobile': '2094665341'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '5307561800'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '5592518463'},
#  {'email': 'providerservices@hpsj.com~', 'mobile': '2099432000'},
#  {'npi': '1780697987',
#   'first_name': 'Earl',
#   'last_name': 'Taylor',
#   'dob': '01-24-1933',
#   'email': 'rrnkumar@yahoo.com',
#   'mobile': '2099831681'},
#  {'email': 'shorne@silverliningtrans.com', 'mobile': '2094750708'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2096032583'},
#  {'email': 'central1mobility@gmail.com', 'mobile': '2094757953'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2093737051'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095795795'},
#  {'email': 'kumarstransport@yahoo.com', 'mobile': '2092340377'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2097234109'},
#  {'email': 'gemini413@sbcglobal.net', 'mobile': '2097403943'},
#  {'email': 'providerservices@hpsj.com~', 'mobile': '2098473011'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094643024'},
#  {'email': 'procarepando@att.net', 'mobile': '2095442273'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '7049691335'},
#  {'email': 'r.barsamian@midvalleyhs.com', 'mobile': '2095311858'},
#  {'email': 'sjopmaribel@gmail.com', 'mobile': '2099320170'},
#  {'email': 'gtoensing@activstyle.com', 'mobile': '5594561774'},
#  {'email': 'tracy@capstoneorthopedic.com', 'mobile': '2098348600'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098513782'},
#  {'email': 'lsoung@sbcglobal.net', 'mobile': '2094655107'},
#  {'npi': '1174510747',
#   'first_name': 'Lian-Sen',
#   'last_name': 'Soung',
#   'dob': '02-05-1945',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '6618616160'},
#  {'email': 'providerservices@hpsj.com~', 'mobile': '2098260591'},
#  {'email': 'haig@westerndrug.com', 'mobile': '8553502424'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2093889175'},
#  {'email': 'providerservices@hpsj.com~', 'mobile': '2098260591'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098351500'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095264500'},
#  {'email': 'anamiramontes@hotmail.com', 'mobile': '2096311956'},
#  {'npi': '1033239843',
#   'first_name': 'Ana',
#   'last_name': 'Miramontes',
#   'dob': '05-31-1972',
#   'email': 'damiana@spmbs.com~',
#   'mobile': '3109878708'},
#  {'npi': '1376794479',
#   'first_name': 'Sheila',
#   'last_name': 'Mulvihill',
#   'dob': '08-01-1978',
#   'email': 'andrea@yosemiteboneandjoint.com',
#   'mobile': '2092623064'},
#  {'npi': '1598868549',
#   'first_name': 'Arnold',
#   'last_name': 'Lim',
#   'dob': '03-02-1975',
#   'email': 'andrea@yosemiteboneandjoint.com',
#   'mobile': '2092613064'},
#  {'npi': '1598868549',
#   'first_name': 'Arnold',
#   'last_name': 'Lim',
#   'dob': '03-02-1975',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2095781211'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095645000'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2096674200'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '9254846400'},
#  {'email': 'careplushs@gmail.com', 'mobile': '9254492180'},
#  {'email': 'desha.mcleod@hospiceheart.org', 'mobile': '2095786300'},
#  {'email': 'dougb@aspenskilledhealth.com', 'mobile': '2093343825'},
#  {'email': 'khorton@vhsacramento.com', 'mobile': '9163519151'},
#  {'email': 'yvonne@professionalbilling.net', 'mobile': '2095725888'},
#  {'email': 'growe@infinitycares.com', 'mobile': '8002941461'},
#  {'email': 'sbasra@healthyliving-modesto.com', 'mobile': '2093007898'},
#  {'email': 'maria.morales@phhhc.com', 'mobile': '2094223700'},
#  {'email': 'manoj.bains@encompasshealth.com', 'mobile': '2098573509'},
#  {'email': 'torainshandy@gmail.com', 'mobile': '5107553094'},
#  {'email': 'allison-boyd@sbcglobal.net', 'mobile': '2093514735'},
#  {'npi': '1326234220',
#   'first_name': 'Allison',
#   'last_name': 'Boyd',
#   'dob': '12-24-1965',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094642605'},
#  {'npi': '1790844769',
#   'first_name': 'Aejaz',
#   'last_name': 'Ahmed',
#   'dob': '06-04-1954',
#   'email': 'rparikh5@yahoo.com',
#   'mobile': '2099379010'},
#  {'npi': '1306067012',
#   'first_name': 'Rajul',
#   'last_name': 'Parikh',
#   'dob': '09-15-1950',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2093393797'},
#  {'email': 'damirhamzeh@comcast.net', 'mobile': '2096654412'},
#  {'npi': '1174523096',
#   'first_name': 'Mehrdad',
#   'last_name': 'Amirhamzeh',
#   'dob': '04-27-1961',
#   'email': 'damirhamzeh@comcast.net',
#   'mobile': '2096654412'},
#  {'npi': '1174523096',
#   'first_name': 'Mehrdad',
#   'last_name': 'Amirhamzeh',
#   'dob': '04-27-1961',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2092390320'},
#  {'npi': '1063590560',
#   'first_name': 'Min',
#   'last_name': 'Wu',
#   'dob': '10-02-1973',
#   'email': 'providerservices@hpsj.com~',
#   'mobile': '4155676600'},
#  {'email': 'chrisp@tenspede.com', 'mobile': '2099449990'},
#  {'email': 'pdmdhtrl@gmail.com', 'mobile': '2099484200'},
#  {'npi': '1356386510',
#   'first_name': 'Poonam',
#   'last_name': 'Duggal',
#   'dob': '01-05-1964',
#   'email': 'johnovertonsr@gmail.com',
#   'mobile': '2098513883'},
#  {'npi': '1144261173',
#   'first_name': 'John',
#   'last_name': 'Overton',
#   'dob': '08-10-1941',
#   'email': 'andrea@ezsleepclub.com',
#   'mobile': '8885880202'},
#  {'email': 'vestproviderupdate@hill-room.com', 'mobile': '8004264224'},
#  {'email': 'duccnguyenmdinc@comcast.net', 'mobile': '2098333320'},
#  {'npi': '1356315410',
#   'first_name': 'Duc',
#   'last_name': 'Nguyen',
#   'dob': '05-16-1966',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2095224985'},
#  {'email': 'aspsyd@gmail.com', 'mobile': '2096104721'},
#  {'npi': '1457479990',
#   'first_name': 'Alison',
#   'last_name': 'Stingle',
#   'dob': '12-01-1971',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '9164540444'},
#  {'email': 'riversidetherapygroup@gmail.com', 'mobile': '2093682532'},
#  {'npi': '1093144198',
#   'first_name': 'Mariann',
#   'last_name': 'Arney',
#   'dob': '02-01-1959',
#   'email': 'odomsharon@gmail.com',
#   'mobile': '2094506245'},
#  {'npi': '1740469626',
#   'first_name': 'Sharon',
#   'last_name': 'Odom',
#   'dob': '11-19-1973',
#   'email': 'yypersimmon@gmail.com',
#   'mobile': '2099550805'},
#  {'npi': '1710337969',
#   'first_name': 'Shoanie',
#   'last_name': 'Young',
#   'dob': '10-16-1982',
#   'email': 'insidethebox88@gmail.com',
#   'mobile': '2095076603'},
#  {'npi': '1356770564',
#   'first_name': 'Margarita',
#   'last_name': 'Garcia',
#   'dob': '12-29-1988',
#   'email': 'shelly.master@aseracare.com',
#   'mobile': '9168135004'},
#  {'email': 'elizabethlmft@outlook.com', 'mobile': '2096910753'},
#  {'npi': '1417312281',
#   'first_name': 'Elizabeth',
#   'last_name': 'Choate',
#   'dob': '05-19-1973',
#   'email': 'mttaborcounseling@pauboxmail.com',
#   'mobile': '2094511010'},
#  {'npi': '1821420316',
#   'first_name': 'Derek',
#   'last_name': 'Washington',
#   'dob': '09-21-1939',
#   'email': 'karagot@ah.org',
#   'mobile': '2093718700'},
#  {'email': 'maria.g.rameno@gmail.com~', 'mobile': '2096611107'},
#  {'npi': '1649538869',
#   'first_name': 'Maria',
#   'last_name': 'Rameno',
#   'dob': '12-30-1970',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'eeckart@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1124186101',
#   'first_name': 'Carrie',
#   'last_name': 'Janiski',
#   'dob': '04-27-1982',
#   'email': 'asiegel@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'eeckart@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'jfregoso@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1437527348',
#   'first_name': 'Sushma',
#   'last_name': 'Indukuri',
#   'dob': '03-25-1981',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'credentialingstaff@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1124186101',
#   'first_name': 'Carrie',
#   'last_name': 'Janiski',
#   'dob': '04-27-1982',
#   'email': 'credentialingstaff@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1124186101',
#   'first_name': 'Carrie',
#   'last_name': 'Janiski',
#   'dob': '04-27-1982',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1093029001',
#   'first_name': 'Diane',
#   'last_name': 'Renteria',
#   'dob': '02-19-1971',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'ccart@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'shurst@gvhc.org',
#   'mobile': '8666824842'},
#  {'npi': '1306283239',
#   'first_name': 'Ibraheem',
#   'last_name': 'Al Shareef',
#   'dob': '03-23-1981',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '8666824842'},
#  {'npi': '1962583617',
#   'first_name': 'Ellen',
#   'last_name': 'Piernot',
#   'dob': '03-30-1977',
#   'email': 'smgerling@gmail.com',
#   'mobile': '2095415375'},
#  {'npi': '1477616464',
#   'first_name': 'Sally',
#   'last_name': 'Gerling',
#   'dob': '04-07-1958',
#   'email': 'soniaramirezlmft@gmail.com~',
#   'mobile': '2096047243'},
#  {'npi': '1427186303',
#   'first_name': 'Sonia',
#   'last_name': 'Andalon',
#   'dob': '10-18-1969',
#   'email': 'credentialing@cpsych.com',
#   'mobile': '2098232246'},
#  {'npi': '1093002636',
#   'first_name': 'Zainab',
#   'last_name': 'Al-Dhaher',
#   'dob': '02-03-1982',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096763069'},
#  {'npi': '1003360108',
#   'first_name': 'Anissa',
#   'last_name': 'Brown',
#   'dob': '06-15-1986',
#   'email': 'familytherapylodi@gmail.com~',
#   'mobile': '2098004475'},
#  {'npi': '1639306061',
#   'first_name': 'Jennifer',
#   'last_name': 'Blume',
#   'dob': '04-10-1970',
#   'email': 'mb@valleyriverortho.com',
#   'mobile': '2094002959'},
#  {'npi': '1497983498',
#   'first_name': 'Naseem',
#   'last_name': 'Beauchman',
#   'dob': '06-05-1982',
#   'email': 'credentialing@brighthearthealth.com',
#   'mobile': '8008922695'},
#  {'npi': '1922363183',
#   'first_name': 'Samuel',
#   'last_name': 'Park',
#   'dob': '07-15-1984',
#   'email': 'receptionist.marteleye@gmail.com',
#   'mobile': '9166356161'},
#  {'npi': '1851312300',
#   'first_name': 'James',
#   'last_name': 'Martel',
#   'dob': '10-15-1955',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '9252406300'},
#  {'email': 'foothillsmedicaltransport@gmail.com', 'mobile': '8002170876'},
#  {'email': 'fshams@aplushhci.com', 'mobile': '9255233303'},
#  {'email': 'crystalbarreralcsw@gmail.com', 'mobile': '2096063886'},
#  {'npi': '1902049240',
#   'first_name': 'Crystal',
#   'last_name': 'Barrera',
#   'dob': '02-23-1981',
#   'email': 'cristina@elportalcancercenter.com',
#   'mobile': '2097263410'},
#  {'npi': '1881702645',
#   'first_name': 'Ram',
#   'last_name': 'Chillar',
#   'dob': '05-04-1942',
#   'email': 'cristina@elportalcancercenter.com',
#   'mobile': '5596734600'},
#  {'npi': '1184003402',
#   'first_name': 'Kelly',
#   'last_name': 'Flores',
#   'dob': '09-29-1979',
#   'email': 'cristina@elportalcancercenter.com',
#   'mobile': '2098266554'},
#  {'npi': '1184003402',
#   'first_name': 'Kelly',
#   'last_name': 'Flores',
#   'dob': '09-29-1979',
#   'email': 'judee@stocktoncardio.com',
#   'mobile': '2099481234'},
#  {'npi': '1033223060',
#   'first_name': 'James',
#   'last_name': 'Morrissey',
#   'dob': '07-09-1936',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2092275133'},
#  {'email': 'alopez@sevapain.com', 'mobile': '2092795540'},
#  {'npi': '1982951554',
#   'first_name': 'Gurpreet',
#   'last_name': 'Dhaliwal',
#   'dob': '01-06-1984',
#   'email': 'coffeeortho@aol.com',
#   'mobile': '2095244438'},
#  {'npi': '1427061092',
#   'first_name': 'Robert',
#   'last_name': 'Cash',
#   'dob': '06-21-1962',
#   'email': 'dianerthomas23@gmail.com',
#   'mobile': '2094424171'},
#  {'npi': '1376882357',
#   'first_name': 'Diane',
#   'last_name': 'Thomas',
#   'dob': '02-21-1984',
#   'email': 'judee@stocktoncardio.com',
#   'mobile': '2099481234'},
#  {'npi': '1033223060',
#   'first_name': 'James',
#   'last_name': 'Morrissey',
#   'dob': '07-09-1936',
#   'email': 'karenjacka3914@comcast.net',
#   'mobile': '2094836474'},
#  {'npi': '1790908788',
#   'first_name': 'Karen',
#   'last_name': 'Jacka',
#   'dob': '10-27-1961',
#   'email': 'mgodoy@arhcsac.com',
#   'mobile': '9162094400'},
#  {'email': 'jy@pinnaclesurgicalassociates.com', 'mobile': '2097404686'},
#  {'npi': '1750551792',
#   'first_name': 'Andrea',
#   'last_name': 'French',
#   'dob': '05-08-1972',
#   'email': 'jy@pinnaclesurgicalassociates.com',
#   'mobile': '2097404686'},
#  {'npi': '1750551792',
#   'first_name': 'Andrea',
#   'last_name': 'French',
#   'dob': '05-08-1972',
#   'email': 'judee@stocktoncardio.com',
#   'mobile': '2099481234'},
#  {'npi': '1467420711',
#   'first_name': 'Donald',
#   'last_name': 'Stowell',
#   'dob': '05-06-1953',
#   'email': 'admin@sharmainedbarneslmft.com',
#   'mobile': '2094758428'},
#  {'npi': '1477754661',
#   'first_name': 'Sharmaine',
#   'last_name': 'Barnes',
#   'dob': '11-12-1962',
#   'email': 'jsmith3575@comcast.net',
#   'mobile': '2099856844'},
#  {'npi': '1548304751',
#   'first_name': 'Jennifer',
#   'last_name': 'Monnich-Smith',
#   'dob': '01-21-1965',
#   'email': 'lodifamilytherapy@gmail.com~',
#   'mobile': '8053051639'},
#  {'npi': '1780741546',
#   'first_name': 'Michelle',
#   'last_name': 'Besse',
#   'dob': '10-06-1980',
#   'email': 'danl.verdone5@gmail.com',
#   'mobile': '2095731333'},
#  {'npi': '1245383496',
#   'first_name': 'Danl',
#   'last_name': 'Verdone',
#   'dob': '05-29-1972',
#   'email': 'bhmmft@att.net',
#   'mobile': '2096386673'},
#  {'npi': '1649280017',
#   'first_name': 'Byron',
#   'last_name': 'Miller',
#   'dob': '10-15-1959',
#   'email': 'nowel@goldenhospice.com',
#   'mobile': '2098322224'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098322224'},
#  {'email': 'salehtherapy@gmail.com', 'mobile': '2097358367'},
#  {'npi': '1265725279',
#   'first_name': 'Melonie',
#   'last_name': 'Saleh',
#   'dob': '11-06-1969',
#   'email': 'deena.souza.allumlmft@gmail.com~',
#   'mobile': '2096029992'},
#  {'npi': '1366627093',
#   'first_name': 'Deena',
#   'last_name': 'Souza-Allum',
#   'dob': '03-10-1972',
#   'email': 'johnquinones@hotmail.com',
#   'mobile': '2094994251'},
#  {'npi': '1386663045',
#   'first_name': 'John',
#   'last_name': 'Quinones',
#   'dob': '12-23-1956',
#   'email': 'mafajiemd@gmail.com',
#   'mobile': '2099109123'},
#  {'npi': '1891079455',
#   'first_name': 'Fajie',
#   'last_name': 'Ma',
#   'dob': '04-25-1963',
#   'email': 'ebsbillersf@gmail.com',
#   'mobile': '2095710003'},
#  {'npi': '1376663161',
#   'first_name': 'Karen',
#   'last_name': 'Boltwood',
#   'dob': '03-23-1954',
#   'email': 'russell.ramos@eden-health.com',
#   'mobile': '9166814949'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094734211'},
#  {'npi': '1063584662',
#   'first_name': 'Genola',
#   'last_name': 'Spoonhour',
#   'dob': '10-05-1942',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2092773707'},
#  {'npi': '1528103736',
#   'first_name': 'Jason',
#   'last_name': 'Vaughan',
#   'dob': '04-08-1971',
#   'email': 'stocktonoptometry@gmail.com',
#   'mobile': '2099512020'},
#  {'npi': '1669452801',
#   'first_name': 'David',
#   'last_name': 'Benkle',
#   'dob': '08-21-1954',
#   'email': 'moreno.lcsw@gmail.com',
#   'mobile': '2092223396'},
#  {'npi': '1710241310',
#   'first_name': 'Michelle',
#   'last_name': 'Moreno',
#   'dob': '02-25-1978',
#   'email': 'info@starnonemergenttransportation.com',
#   'mobile': '2092146186'},
#  {'email': 'sherron18@yahoo.com', 'mobile': '2092223158'},
#  {'npi': '1447317102',
#   'first_name': 'Suzanne',
#   'last_name': 'Herron',
#   'dob': '05-20-1956',
#   'email': 'jruedalcsw@gmail.com',
#   'mobile': '2093682532'},
#  {'npi': '1376962308',
#   'first_name': 'Jackelin',
#   'last_name': 'Rueda',
#   'dob': '05-12-1988',
#   'email': 'mpramirez129@gmail.com~',
#   'mobile': '2095053611'},
#  {'npi': '1376877951',
#   'first_name': 'Maribel',
#   'last_name': 'Peral-Ramirez',
#   'dob': '07-06-1980',
#   'email': 'lockettsranch@yahoo.com',
#   'mobile': '2092331927'},
#  {'npi': '1811018724',
#   'first_name': 'Dusty',
#   'last_name': 'Lockett',
#   'dob': '08-26-1973',
#   'email': 'kimwarmsley@yahoo.com',
#   'mobile': '2099058809'},
#  {'npi': '1083890529',
#   'first_name': 'Kimberly',
#   'last_name': 'Warmsley',
#   'dob': '06-29-1977',
#   'email': 'maryamesho@gmail.com',
#   'mobile': '2096686900'},
#  {'npi': '1215000633',
#   'first_name': 'Maryam',
#   'last_name': 'Esho',
#   'dob': '09-02-1961',
#   'email': 'cfvr4@aol.com',
#   'mobile': '2099863500'},
#  {'npi': '1831255439',
#   'first_name': 'John',
#   'last_name': 'Thompson',
#   'dob': '08-19-1949',
#   'email': 'acampomft@gmail.com',
#   'mobile': '2095415969'},
#  {'npi': '1437285756',
#   'first_name': 'Annette',
#   'last_name': 'Campo',
#   'dob': '08-04-1966',
#   'email': 'barbara.hayford@hospiceheart.org',
#   'mobile': '2094776300'},
#  {'email': 'providerservices@hpsj.com~', 'mobile': '2098632132'},
#  {'npi': '1295168227',
#   'first_name': 'Araceli',
#   'last_name': 'Vigil',
#   'dob': '02-15-1986',
#   'email': 'maria.morales@phhhc.com',
#   'mobile': '2094223700'},
#  {'email': 'julio@myunihealth.com', 'mobile': '4155626056'},
#  {'npi': '1629106141',
#   'first_name': 'Julio',
#   'last_name': 'Lagos',
#   'dob': '08-23-1982',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2095515100'},
#  {'email': 'zmora@pacmedical.com', 'mobile': '2094904515'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095230202'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095230202'},
#  {'email': 'katrina1.hinkle@tenethealth.com', 'mobile': '2095710288'},
#  {'npi': '1912918962',
#   'first_name': 'Kyle',
#   'last_name': 'Heron',
#   'dob': '01-18-1961',
#   'email': 'diana.silveira@tenethealth.com',
#   'mobile': '2095710288'},
#  {'npi': '1972761211',
#   'first_name': 'Gregory',
#   'last_name': 'Helbig',
#   'dob': '11-09-1974',
#   'email': 'gastrodoc209@gmail.com',
#   'mobile': '2099410791'},
#  {'npi': '1548335185',
#   'first_name': 'Iftikhar',
#   'last_name': 'Malik',
#   'dob': '09-11-1950',
#   'email': 'quinnod@sbcglobal.net',
#   'mobile': '2094767040'},
#  {'npi': '1528038486',
#   'first_name': 'Quinn',
#   'last_name': 'Nguyen',
#   'dob': '06-10-1972',
#   'email': 'pdold@tokaymb.com',
#   'mobile': '2092422690'},
#  {'npi': '1699780494',
#   'first_name': 'Bhagya',
#   'last_name': 'Nakka',
#   'dob': '09-25-1969',
#   'email': 'diana.silveira@tenethealth.com',
#   'mobile': '2095710288'},
#  {'npi': '1679541528',
#   'first_name': 'Benjamin',
#   'last_name': 'Remington',
#   'dob': '04-30-1967',
#   'email': 'allcitybilling1069@yahoo.com',
#   'mobile': '2092727537'},
#  {'npi': '1598891228',
#   'first_name': 'Victor',
#   'last_name': 'Ho',
#   'dob': '05-09-1965',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2098362223'},
#  {'npi': '1609939099',
#   'first_name': 'Jordan',
#   'last_name': 'Usunov',
#   'dob': '08-17-1947',
#   'email': 'dmfahlen@sbcglobal.net',
#   'mobile': '2095442910'},
#  {'npi': '1679539415',
#   'first_name': 'Mark',
#   'last_name': 'Fahlen',
#   'dob': '08-31-1971',
#   'email': 'tsikes@norcalambulance.com',
#   'mobile': '9254528350'},
#  {'email': 'svalencia4233@gmail.com', 'mobile': '2096486200'},
#  {'npi': '1760503551',
#   'first_name': 'Susan',
#   'last_name': 'Valencia Lopez',
#   'dob': '12-01-1968',
#   'email': 'info@abalancecounseling.com',
#   'mobile': '2092624387'},
#  {'npi': '1265931760',
#   'first_name': 'Bergen',
#   'last_name': 'Filgas',
#   'dob': '09-21-1968',
#   'email': 'info@abalancecounseling.com',
#   'mobile': '2092624387'},
# ...
#   'mobile': '2098488410'},
#  {'npi': '1801824222',
#   'first_name': 'Marc',
#   'last_name': 'Stoner',
#   'dob': '06-15-1953',
#   'email': 'drbechtel@bechtelmd.com',
#   'mobile': '2099393833'},
#  {'email': 'drbechtel@drbechtel.com', 'mobile': '2098512144'},
#  {'npi': '1902860950',
#   'first_name': 'Timothy',
#   'last_name': 'Bechtel',
#   'dob': '04-27-1968',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '7072558825'},
#  {'email': 'mdcvretina@yahoo.com', 'mobile': '2095269500'},
#  {'npi': '1477548667',
#   'first_name': 'Shi-Hwa',
#   'last_name': 'Chang',
#   'dob': '03-09-1959',
#   'email': 'gillobgyn@sbcglobal.net',
#   'mobile': '2099339888'},
#  {'npi': '1972578896',
#   'first_name': 'Andrew',
#   'last_name': 'Chao',
#   'dob': '12-08-1952',
#   'email': 'lucydlczooz@yahoo.com',
#   'mobile': '2098332228'},
#  {'npi': '1790885176',
#   'first_name': 'Rodrigo',
#   'last_name': 'De La Cruz',
#   'dob': '03-13-1965',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096349034'},
#  {'npi': '1710088109',
#   'first_name': 'Daniel',
#   'last_name': 'McCauley',
#   'dob': '11-16-1942',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2093390300'},
#  {'npi': '1235178658',
#   'first_name': 'Harmanjeet',
#   'last_name': 'Dhaliwal',
#   'dob': '06-16-1962',
#   'email': 'larsenanddunnicliff@gmail.com',
#   'mobile': '2094731138'},
#  {'npi': '1295823409',
#   'first_name': 'Gregory',
#   'last_name': 'Dunnicliff',
#   'dob': '01-16-1951',
#   'email': 'drjohnnyfong@yahoo.com',
#   'mobile': '2097252060'},
#  {'npi': '1356641013',
#   'first_name': 'Janelle',
#   'last_name': 'Fong',
#   'dob': '04-29-1978',
#   'email': 'fj3838@gmail.com',
#   'mobile': '2092487432'},
#  {'npi': '1356641013',
#   'first_name': 'Janelle',
#   'last_name': 'Fong',
#   'dob': '04-29-1978',
#   'email': 'daniel@cvemg.com',
#   'mobile': '2095798800'},
#  {'npi': '1508991993',
#   'first_name': 'Michael',
#   'last_name': 'Sakamoto',
#   'dob': '04-11-1954',
#   'email': 'daniel@cvemg.com',
#   'mobile': '2099523700'},
#  {'npi': '1083021752',
#   'first_name': 'Vikram',
#   'last_name': 'Girn',
#   'dob': '02-11-1987',
#   'email': 'daniel@cvemg.com',
#   'mobile': '2092395303'},
#  {'npi': '1083021752',
#   'first_name': 'Vikram',
#   'last_name': 'Girn',
#   'dob': '02-11-1987',
#   'email': 'mharderopt@gmail.com',
#   'mobile': '2095964360'},
#  {'npi': '1093787459',
#   'first_name': 'Mark',
#   'last_name': 'Harder',
#   'dob': '08-16-1954',
#   'email': 'magimbi@magimbicares.org',
#   'mobile': '2098322095'},
#  {'npi': '1851470959',
#   'first_name': 'Athanasios',
#   'last_name': 'Magimbi',
#   'dob': '02-07-1957',
#   'email': 'pucmalak@yahoo.com',
#   'mobile': '2094759500'},
#  {'npi': '1104931260',
#   'first_name': 'Taymour',
#   'last_name': 'Malak',
#   'dob': '03-06-1953',
#   'email': 'ramirez672000@yahoo.com',
#   'mobile': '2094655891'},
#  {'npi': '1104931260',
#   'first_name': 'Taymour',
#   'last_name': 'Malak',
#   'dob': '03-06-1953',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2099449100'},
#  {'npi': '1750316295',
#   'first_name': 'Jeffrey',
#   'last_name': 'Mansoor',
#   'dob': '06-05-1951',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2099445550'},
#  {'npi': '1750316295',
#   'first_name': 'Jeffrey',
#   'last_name': 'Mansoor',
#   'dob': '06-05-1951',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094669694'},
#  {'npi': '1750316295',
#   'first_name': 'Jeffrey',
#   'last_name': 'Mansoor',
#   'dob': '06-05-1951',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2099553047'},
#  {'npi': '1750316295',
#   'first_name': 'Jeffrey',
#   'last_name': 'Mansoor',
#   'dob': '06-05-1951',
#   'email': 'tforshey@sierrahealth.net~',
#   'mobile': '2099445550'},
#  {'npi': '1750316295',
#   'first_name': 'Jeffrey',
#   'last_name': 'Mansoor',
#   'dob': '06-05-1951',
#   'email': 'recovery@sbcglobal.net',
#   'mobile': '2094646016'},
#  {'npi': '1801866777',
#   'first_name': 'May',
#   'last_name': 'Mardini',
#   'dob': '11-04-1965',
#   'email': 'slee@heritageeye.com',
#   'mobile': '2094655933'},
#  {'npi': '1730154592',
#   'first_name': 'Kenneth',
#   'last_name': 'Miselis',
#   'dob': '09-17-1951',
#   'email': 'mamgmd1@gmail.com',
#   'mobile': '9164699337'},
#  {'npi': '1083701007',
#   'first_name': 'Yung',
#   'last_name': 'Yim',
#   'dob': '08-30-1957',
#   'email': 'sreddy@stan-card.com',
#   'mobile': '2095219661'},
#  {'npi': '1114040029',
#   'first_name': 'Mimsie',
#   'last_name': 'Farrar',
#   'dob': '02-08-1953',
#   'email': 'sreddy@stan-card.com',
#   'mobile': '2098475757'},
#  {'npi': '1114040029',
#   'first_name': 'Mimsie',
#   'last_name': 'Farrar',
#   'dob': '02-08-1953',
#   'email': 'sreddy@stan-card.com',
#   'mobile': '2095219661'},
#  {'npi': '1114040029',
#   'first_name': 'Mimsie',
#   'last_name': 'Farrar',
#   'dob': '02-08-1953',
#   'email': 'dcasillas@stan-card.com~',
#   'mobile': '2095219661'},
#  {'npi': '1386628212',
#   'first_name': 'Kent',
#   'last_name': 'Wong',
#   'dob': '01-13-1967',
#   'email': 'mleeyang1@yahoo.com',
#   'mobile': '2096343300'},
#  {'npi': '1265415525',
#   'first_name': 'Natalie',
#   'last_name': 'Mattos-Perry',
#   'dob': '12-30-1980',
#   'email': 'sussery@gmail.com',
#   'mobile': '2095220600'},
#  {'npi': '1780624619',
#   'first_name': 'Yahya',
#   'last_name': 'Talieh',
#   'dob': '07-04-1966',
#   'email': 'cheryle.pickle@modestokidney.com',
#   'mobile': '2095261606'},
#  {'npi': '1740588680',
#   'first_name': 'Yuqiang',
#   'last_name': 'Ge',
#   'dob': '09-14-1966',
#   'email': 'lisa.rhodeman@modestokidney.com',
#   'mobile': '2096327746'},
#  {'npi': '1740588680',
#   'first_name': 'Yuqiang',
#   'last_name': 'Ge',
#   'dob': '09-14-1966',
#   'email': 'lisa.rhodeman@modestokidney.com',
#   'mobile': '2098920615'},
#  {'npi': '1740588680',
#   'first_name': 'Yuqiang',
#   'last_name': 'Ge',
#   'dob': '09-14-1966',
#   'email': 'dperry@apexmedicalcorp.com',
#   'mobile': '2098262222'},
#  {'npi': '1780615542',
#   'first_name': 'Karthikeya',
#   'last_name': 'Devireddy',
#   'dob': '08-13-1950',
#   'email': 'kidscare@modestopediatrics.com',
#   'mobile': '2095220001'},
#  {'npi': '1437120532',
#   'first_name': 'Ann',
#   'last_name': 'Truscello',
#   'dob': '07-16-1960',
#   'email': 'rajmd@sanramonucc.com',
#   'mobile': '2098255155'},
#  {'npi': '1740431246',
#   'first_name': 'Rajesh',
#   'last_name': 'Maheshwari',
#   'dob': '12-02-1978',
#   'email': 'emilano@lodihealth.org',
#   'mobile': '2093397585'},
#  {'npi': '1558339119',
#   'first_name': 'Elvira',
#   'last_name': 'Milano',
#   'dob': '06-10-1954',
#   'email': 'naujla@sbcglobal.net',
#   'mobile': '2097231020'},
#  {'npi': '1275637506',
#   'first_name': 'Nirmal',
#   'last_name': 'Aujla',
#   'dob': '04-03-1954',
#   'email': 'marchlanepeds73f@yahoo.com',
#   'mobile': '2099525555'},
#  {'npi': '1043224769',
#   'first_name': 'Deborah',
#   'last_name': 'Hastie',
#   'dob': '04-30-1952',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2099520483'},
#  {'npi': '1841377405',
#   'first_name': 'Denise',
#   'last_name': 'Guendert',
#   'dob': '04-19-1963',
#   'email': 'cbrown@sacent.com',
#   'mobile': '2099520483'},
#  {'npi': '1932201589',
#   'first_name': 'Spencer',
#   'last_name': 'Lowe',
#   'dob': '06-22-1949',
#   'email': 'montelar@ah.org',
#   'mobile': '2093339617'},
#  {'npi': '1134385354',
#   'first_name': 'Walter',
#   'last_name': 'Lampa',
#   'dob': '03-09-1973',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2097773500'},
#  {'npi': '1609032358',
#   'first_name': 'Raminder',
#   'last_name': 'Mand',
#   'dob': '07-30-1969',
#   'email': 'acpt@att.net',
#   'mobile': '2098308855'},
#  {'npi': '1114012572',
#   'first_name': 'Kealoha',
#   'last_name': 'Miller',
#   'dob': '04-09-1977',
#   'email': 'acpt@att.net',
#   'mobile': '2098308855'},
#  {'npi': '1114012572',
#   'first_name': 'Kealoha',
#   'last_name': 'Miller',
#   'dob': '04-09-1977',
#   'email': 'juneadams@calmed4u.com',
#   'mobile': '2093852240'},
#  {'npi': '1265656417',
#   'first_name': 'Fariba',
#   'last_name': 'Amani',
#   'dob': '09-06-1969',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096688030'},
#  {'npi': '1265656417',
#   'first_name': 'Fariba',
#   'last_name': 'Amani',
#   'dob': '09-06-1969',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2093852240'},
#  {'npi': '1265656417',
#   'first_name': 'Fariba',
#   'last_name': 'Amani',
#   'dob': '09-06-1969',
#   'email': 'drreddy@centralvalleycardiovascular.com',
#   'mobile': '2098264800'},
#  {'npi': '1265656417',
#   'first_name': 'Fariba',
#   'last_name': 'Amani',
#   'dob': '09-06-1969',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096688030'},
#  {'npi': '1710183165',
#   'first_name': 'Oussama',
#   'last_name': 'Dagher',
#   'dob': '08-22-1972',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096688030'},
#  {'npi': '1265656417',
#   'first_name': 'Fariba',
#   'last_name': 'Amani',
#   'dob': '09-06-1969',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2096688030'},
#  {'npi': '1265656417',
#   'first_name': 'Fariba',
#   'last_name': 'Amani',
#   'dob': '09-06-1969',
#   'email': 'bqnguyen@gmail.com',
#   'mobile': '2094758144'},
#  {'npi': '1821032475',
#   'first_name': 'Bao',
#   'last_name': 'Nguyen',
#   'dob': '08-01-1973',
#   'email': 'kimmi_2018@yahoo.com',
#   'mobile': '2093393797'},
#  {'npi': '1790722718',
#   'first_name': 'Tareq',
#   'last_name': 'Ali',
#   'dob': '08-15-1962',
#   'email': 'drbajwa5345@gmail.com',
#   'mobile': '2094784041'},
#  {'npi': '1871871681',
#   'first_name': 'Tanveer',
#   'last_name': 'Bajwa',
#   'dob': '01-16-1978',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094686820'},
#  {'email': 'dperry@sjgh.org', 'mobile': '2094686820'},
#  {'npi': '1184677940',
#   'first_name': 'Senzan',
#   'last_name': 'Hsu',
#   'dob': '08-03-1970',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094686820'},
#  {'email': 'dperry@sjgh.org', 'mobile': '2094686820'},
#  {'npi': '1225319270',
#   'first_name': 'Patara',
#   'last_name': 'Rojanavongse',
#   'dob': '05-22-1976',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094686820'},
#  {'email': 'cindy.chock@sbcglobal.net', 'mobile': '2098472201'},
#  {'npi': '1154423994',
#   'first_name': 'Edward',
#   'last_name': 'Chock',
#   'dob': '10-20-1949',
#   'email': 'familyfirstmedicalcare@gmail.com',
#   'mobile': '2095223362'},
#  {'npi': '1447232988',
#   'first_name': 'Lisa',
#   'last_name': 'Gil',
#   'dob': '04-25-1973',
#   'email': 'familyfirstmedicalcare@gmail.com',
#   'mobile': '2093223362'},
#  {'npi': '1427186303',
#   'first_name': 'Sonia',
#   'last_name': 'Andalon',
#   'dob': '10-18-1969',
#   'email': 'familyfirstmedicalcare@gmail.com',
#   'mobile': '2095223362'},
#  {'npi': '1558676130',
#   'first_name': 'Sandra',
#   'last_name': 'Centeno',
#   'dob': '12-15-1982',
#   'email': 'jsdpiemod@aol.com',
#   'mobile': '2094920735'},
#  {'npi': '1295891224',
#   'first_name': 'Jonathan',
#   'last_name': 'Davidson',
#   'dob': '07-27-1959',
#   'email': 'melaskew13@gmail.com',
#   'mobile': '2092245236'},
#  {'npi': '1699760769',
#   'first_name': 'Ezell',
#   'last_name': 'Askew',
#   'dob': '03-04-1964',
#   'email': 'calebf@elitephysicaltherapy.com',
#   'mobile': '2092502226'},
#  {'npi': '1265716765',
#   'first_name': 'Caleb',
#   'last_name': 'Fontes',
#   'dob': '05-29-1981',
#   'email': 'helahi1002@yahoo.com',
#   'mobile': '2098244400'},
#  {'npi': '1154657716',
#   'first_name': 'Foad',
#   'last_name': 'Elahi',
#   'dob': '07-12-1965',
#   'email': 'anupa.harvey@sjpodiatry.com',
#   'mobile': '2098232700'},
#  {'npi': '1033475678',
#   'first_name': 'Jack',
#   'last_name': 'Harvey',
#   'dob': '07-06-1982',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2094646422'},
#  {'npi': '1396007100',
#   'first_name': 'Jennifer',
#   'last_name': 'Williams',
#   'dob': '04-15-1978',
#   'email': 'providerrelations@calmed4u.com',
#   'mobile': '2096560183'},
#  {'npi': '1588808703',
#   'first_name': 'Jennifer',
#   'last_name': 'Leoniak',
#   'dob': '02-18-1980',
#   'email': 'providerrelations@calmed4u.com',
#   'mobile': '2096560183'},
#  {'npi': '1588808703',
#   'first_name': 'Jennifer',
#   'last_name': 'Leoniak',
#   'dob': '02-18-1980',
#   'email': 'iris@physicaltherapylodi.com',
#   'mobile': '2092070849'},
#  {'npi': '1912104472',
#   'first_name': 'Gabriel',
#   'last_name': 'Enescu',
#   'dob': '02-07-1958',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2095244438'},
#  {'npi': '1538117056',
#   'first_name': 'Paul',
#   'last_name': 'Braaton',
#   'dob': '08-21-1961',
#   'email': 'orthogold@aol.com',
#   'mobile': '2095244438'},
#  {'npi': '1780929034',
#   'first_name': 'Julie',
#   'last_name': 'Scherer',
#   'dob': '04-10-1983',
#   'email': 'credentailing@lagsspine.com',
#   'mobile': '2092840729'},
#  {'npi': '1992799704',
#   'first_name': 'Francis',
#   'last_name': 'Lagattuta',
#   'dob': '08-20-1958',
#   'email': 'credentialing@lagsspine.com',
#   'mobile': '2092840729'},
#  {'npi': '1558740357',
#   'first_name': 'Analene',
#   'last_name': 'Cesar',
#   'dob': '03-20-1961',
#   'email': 'aramirez@lagsspine.com',
#   'mobile': '2094253815'},
#  {'npi': '1558740357',
#   'first_name': 'Analene',
#   'last_name': 'Cesar',
#   'dob': '03-20-1961',
#   'email': 'contracting@lagsspine.com',
#   'mobile': '2092840738'},
#  {'npi': '1992799704',
#   'first_name': 'Francis',
#   'last_name': 'Lagattuta',
#   'dob': '08-20-1958',
#   'email': 'aramirez@lagsspine.com',
#   'mobile': '2092387497'},
#  {'npi': '1912978263',
#   'first_name': 'Marya',
#   'last_name': 'Oakes',
#   'dob': '09-19-1961',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2095374701'},
#  {'npi': '1194151704',
#   'first_name': 'Harinder',
#   'last_name': 'Jhatu',
#   'dob': '07-17-1982',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2095374700'},
#  {'npi': '1154650927',
#   'first_name': 'Jennifer',
#   'last_name': 'Leavens',
#   'dob': '07-25-1980',
#   'email': 'noelii0352@gmail.com',
#   'mobile': '2096248780'},
#  {'npi': '1538153713',
#   'first_name': 'Pardeep',
#   'last_name': 'Brar',
#   'dob': '09-21-1971',
#   'email': 'providerservices@hpsj.com',
#   'mobile': '2098254685'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2096641121'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095215713'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098696499'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095994686'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094729684'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2099516544'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2099523494'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2092392018'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2096696446'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098362316'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098361460'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098451860'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098926182'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2093693648'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095294810'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095752429'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2093685112'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095259430'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095221093'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095374824'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095234932'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2093697403'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095274600'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2096674919'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095516030'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2099569444'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094739170'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098300976'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098621208'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2099480950'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2094785062'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2096345831'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098307388'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098474279'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098471324'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2098231949'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2096699704'},
#  {'email': 'providerservices@hpsj.com', 'mobile': '2095776060'},
#  ...]
